# %%
import napari
import numpy as np
import pandas as pd
from tanalysis import improcess, stitching, traj_analysis

# %%
viewer = napari.Viewer()

dirname = r"D:\pcanaleta\Thunder\SpinningDisk_Test\Compat_1.0-2.0\CD8_APC_WT\Originals\CD8_WT_APC_Thunder.lif"
tracks_dirname = r"D:\pcanaleta\Thunder\SpinningDisk_Test\Compat_1.0-2.0\CD8_APC_WT\Tracks\excel_tracks\CD8_WT_APC_1.0.xlsx"
imgs, names, info = improcess.imread(dirname)
viewer.add_image(imgs)
scale = np.array(info['scale'][::-1])
scale[0] = scale[0]*60

tracks = pd.read_excel(tracks_dirname,)
viewer.add_tracks(tracks[['id', 'time', 'z', 'y', 'x']], scale=scale)
# Out:
# <Tracks layer 'Tracks' at 0x25487e49850>
# Rendering frames...
# 100%|██████████| 676/676 [00:22<00:00, 30.00it/s]
# Rendering frames...
# 100%|██████████| 676/676 [00:22<00:00, 30.49it/s]
# Rendering frames...
# 100%|██████████| 721/721 [00:23<00:00, 31.04it/s]
# Rendering frames...
# 100%|██████████| 662/662 [00:25<00:00, 26.10it/s]
# Rendering frames...
# ...
# 100%|██████████| 663/663 [00:23<00:00, 28.34it/s]
# Rendering frames...
# ...
# 100%|██████████| 666/666 [00:23<00:00, 28.76it/s]
# Rendering frames...
# ...
# 100%|██████████| 666/666 [00:23<00:00, 28.61it/s]
# Rendering frames...
# ...
# 100%|██████████| 666/666 [00:23<00:00, 28.31it/s]
# Rendering frames...
# ...
# 100%|██████████| 891/891 [00:31<00:00, 28.62it/s]
# Rendering frames...
# ...
# 100%|██████████| 946/946 [00:37<00:00, 25.33it/s]

# %%
print(info['scale'][::-1])
