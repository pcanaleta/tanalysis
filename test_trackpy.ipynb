# %%
import trackpy as tp
from tanalysis import improcess

# %%
dirname = r"D:\pcanaleta\Thunder\260327\Compatibility\APC\Originals\APC_2_1.lif"
img, name, _ = improcess.imread(dirname, False, False)
features = tp.locate(img[0], 11)

# %%
print(features)
# Out:
#              x0         x1           x2          x3          mass      size  \
# 0      5.115330   4.840284   154.961566  391.020524  51881.706050  3.627879
# 1      5.138218   5.464675   554.482750  535.681740  64152.157743  3.580261
# 2      4.781002   5.247537   617.758504  744.834413  71101.807477  3.745287
# 3      5.091708   5.041332   736.165960  721.722116  32397.723941  3.575031
# 4      5.096058   5.106091   829.811890  931.707861  66699.405304  3.671061
# ...         ...        ...          ...         ...           ...       ...
# 6263  43.171850  11.713918   880.691966   29.696482  63308.689705  3.774051
# 6264  42.818150  12.100479   882.022105  387.247127  59092.213283  3.643206
# 6265  42.984817  11.906058   976.005556  211.915704  65095.822701  3.709104
# 6266  42.636763  12.438379   982.127387  576.113425  52107.796945  3.555287
# 6267  43.246969  11.693367  1000.973598  378.183120  60778.933417  3.689076
#
#       ecc      signal  raw_mass        ep
# ...
