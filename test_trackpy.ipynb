# %%
import trackpy as tp
from tanalysis import improcess
import numpy as np

# %%
dirname = r"D:\pcanaleta\Thunder\260327\Compatibility\APC\Originals\APC_3_1.lif"
img, name, _ = improcess.imread(dirname, False, False)
features = tp.locate(img[0][30], diameter=(3,31,31), threshold=np.max(img[0])*0.03)
tp.annotate(features, img[0][30][4])
# Out:
# <Axes: >

# %%
a = [1, np.nan]
b = [np.nan, 1]
print(np.divide(a,b))
# Out:
# [nan nan]
